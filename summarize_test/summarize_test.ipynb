# %% [markdown]
# # **This code is for checking how newspaper3k works for scraping**
# Please replace aki_key(s), my_headers, and user_agent to demonstrate by yourself

# %%
pip install openai

# %%
pip install tenacity

# %%
pip install newspaper3k

# %%
import requests
from datetime import date
import pandas as pd
import newspaper
from newspaper import Article
from newspaper import Config

# %% [markdown]
# ## **Make a sample dataset that has 50 different factcheckers' links**

# %%
"""
collect as many variety of factcheckers and links as possible.
Google doesn't provide the list of factcheckers. 
"""
my_headers = <put_your_header_here>
endpoint = 'https://factchecktools.googleapis.com/v1alpha1/claims:search'
query = 'Trump' # most factchecker should have examined 
language = 'en'
max_days = 10000 #Max age of returned search results, in days
page_size = 10000 #Number of pages in the search results
reviewPublisherSiteFilter = '' #Filter by review publisher
api_key = <put_your_api_key>
url = f'{endpoint}?query={query}&languageCode={language}&maxAgeDays={max_days}&key={api_key}&pageSize={page_size}&reviewPublisherSiteFilter={reviewPublisherSiteFilter}'
print(url)
# Out:
# https://factchecktools.googleapis.com/v1alpha1/claims:search?query=Trump&languageCode=en&maxAgeDays=10000&key=AIzaSyAAB8N8l47u7kt_EfrPFUKpwfOPYRmIlGw&pageSize=10000&reviewPublisherSiteFilter=

# %%
req = requests.get(url, headers = my_headers)
print(req.status_code)
data = req.json()
claims = data['claims']
print(len(claims))
print(claims[0].keys())
# Out:
# 200
# 7378
# dict_keys(['text', 'claimReview'])

# %%
queries = []
originators = []
claim_dates = []
reviews = []
publisher_names = []
publisher_sites = []
review_urls = []
titles = []
review_dates = []
ratings = []

for claim in claims: 
    query = claim['text']
    queries.append(query)

for claim in claims: 
    if 'claimant' in claim:
        originator = claim['claimant']
        originators.append(originator)
    else: 
        originators.append('NA')
    
for claim in claims: 
    if 'claimDate' in claim:
        date = claim['claimDate']
        claim_dates.append(date)
    else: 
        claim_dates.append('NA')

for claim in claims: 
    first_review = claim['claimReview'][0]
    reviews.append(first_review) #Most only have one review but some of them have many reviews all saying the same thing so gonna keep it to one to standardise the dataframe

for review in reviews: 
    if 'publisher' in review and 'name' in review['publisher']: 
        publisher_name = review['publisher']['name']
        publisher_names.append(publisher_name)
    else: 
        publisher_names.append('NA')

for review in reviews: 
    if 'publisher' in review and 'site' in review['publisher']: 
        publisher_site = review['publisher']['site']
        publisher_sites.append(publisher_site)
    else: 
        publisher_sites.append('NA')

for review in reviews: 
    if 'url' in review: 
        review_url = review['url']
        review_urls.append(review_url)
    else: 
        review_urls.append('NA')
        
for review in reviews: 
    if 'title' in review: 
        title = review['title']
        titles.append(title)
    else: 
        titles.append('NA')

for review in reviews: 
    if 'reviewDate' in review: 
        review_date = review['reviewDate']
        review_dates.append(review_date)
    else: 
        review_dates.append('NA')

for review in reviews: 
    if 'textualRating' in review: 
        rating = review['textualRating']
        ratings.append(rating)
    else: 
        ratings.append('NA')

# %%
df = pd.DataFrame({'claim': queries, 
                   'originator': originators, 
                   'claim_date': claim_dates, 
                   'review_publisher': publisher_names, 
                   'publisher_site': publisher_sites, 
                   'review_url': review_urls, 
                   'review_title': titles, 
                   'review_date': review_dates, 
                   'verdict': ratings})

# %%
# see how many factcheckers in df and who they are
publishers = df.groupby('review_publisher').size()
print(publishers)

num_publishers = len(publishers.keys())
print('Number of publishers is: ' + str(num_publishers))
# Out:
# review_publisher
# AFP Fact Check                  167
# AP News                           2
# Africa Check                      3
# Alt News                         10
# Australian Associated Press       5
# BBC                              35
# BOOM FactCheck                   22
# CBS News                        144
# Check Your Fact                 329
# Climate Feedback                  2
# Digiteye India                    1
# FACTLY                           10
# FactCheck.org                  1019
# FactRakers                        2
# Full Fact                         7
# Gigafact                         25
# KHOU                              1
# KSDK                              1
# Lead Stories                    263
# NA                               60
# Newschecker                       8
# Newsmeter                         1
# Newsmobile                       38
# Newsweek                        100
# POLYGRAPH.info                    7
# PolitiFact                     2109
# Poynter                           3
# Rappler                           5
# Snopes                         1722
# Snopes.com                       21
# THIP Media                        1
# The Conversation                  8
# The Dispatch                     60
# The France 24 Observers           1
# The Gazette                       1
# The Journal                       2
# The New York Times              275
# The Quint                        14
# The Washington Post             691
# Trump-O-Meter: | PolitiFact       4
# USA Today                       170
# VERA Files                        3
# VERIFYThis.com                   10
# Vox                               7
# WBIR.com                          1
# WFAA                              1
# WKYC                              1
# WTSP.com                          1
# Washington Examiner               3
# YouTurn English                   2
# dtype: int64
# Number of publishers is: 50

# %%
# pick up one url from each factchecker in df
gdf = df.groupby('review_publisher')
sample_df = gdf.apply(lambda x: x.sample(n=1))# sample 1 row from each review_publisher
sample_df.shape
# Out:
# (50, 9)

# %%
# drop index next to review_publisher column 
sample_df = sample_df.reset_index(level='review_publisher', drop=True)

# %%
# Reset index at top left
sample_df = sample_df[0:].reset_index()

# %%
print(sample_df.size)
print(sample_df.dtypes)
print(sample_df.shape)
print(sample_df.columns)
# Out:
# 500
# index                int64
# claim               object
# originator          object
# claim_date          object
# review_publisher    object
# publisher_site      object
# review_url          object
# review_title        object
# review_date         object
# verdict             object
# dtype: object
# (50, 10)
# Index(['index', 'claim', 'originator', 'claim_date', 'review_publisher',
#        'publisher_site', 'review_url', 'review_title', 'review_date',
#        'verdict'],
#       dtype='object')

# %% [markdown]
# # **Look into all websites and scrape contents**

# %%
contents = []

for url in sample_df['review_url']:
  if 'nytimes' in url:
    a = Article(url, language='en') 
    a.download()
    a.parse()
    contents.append(a.title + a.text[:10000])
    """
    NewYorkTimes allows request with user_agent only a few times \
    and then blocks. Above 'if' code solve the problem. 
    """
  else:
    user_agent = <put_your_user_agent_here>
    config = Config()
    config.browser_user_agent = user_agent
    config.request_timeout = 10 # avoid runtime error
    a = Article(url, config=config, language='en') 
    a.download()
    a.parse()
    contents.append(a.title + a.text[:10000])

sample_df['contents'] = contents

# %% [markdown]
# # **Ask GPT-4 to summarize them**

# %%
def gpt_request(query):
    
    """ Send a query to GPT-4 API and return the response """
    
    endpoint = "https://api.openai.com/v1/chat/completions"
    api_key = <put_your_api_key_here>
    
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {api_key}"
    }
    data = {
        "model": "gpt-4",
        # We don't need system message cos we don't ask fact checking
        "messages" : [{"role": "user", "content": query}],
        "max_tokens": 2000,
        "temperature": 0
    }

    response = requests.post(endpoint, headers=headers, json=data)
    response_json = response.json()
    # print(response_json)
    return response_json['choices'][0]['message']['content'].strip()

# %%
summaries = []
for content in sample_df['contents']:
  modified_content = f'Summarize following contents within 50 words, focusing on reasons for its verdict: {content}'
  response = gpt_request(modified_content)
  print(response)
  summaries.append(response)
sample_df['summaries'] = summaries
sample_df
# Out:
# A fabricated tweet attributed to former US President Donald Trump commenting on Oprah Winfrey's interview with Prince Harry and Meghan Markle circulated online. The claim is false as Trump's Twitter account remains suspended since January 2021, and the tweet uses an outdated format that Twitter stopped using in 2017.
# The US Supreme Court has rejected a case calling for the removal of President Joe Biden and hundreds of elected officials over baseless 2020 election fraud claims. Social media users falsely claimed the court would hear the case, but it has been dismissed twice. Legal experts say it is unlikely the Supreme Court will ever hear such a case, as it relies on a false narrative.
# US President Donald Trump did not tweet that South Africa's policy of black economic empowerment was "economic segregation". The claim was made by junk news website XpouZAR.com, which said the tweet had "disappeared before going to press". However, it is illegal for Trump to delete tweets while he is president, and a number of websites are dedicated to keeping track of everything he posts online.
# Rahul Kanwal, News director of India Today, claimed that President Donald Trump has suggested that India could have early access to COVID-19 vaccines being developed in the US since PM Modi accepted his “request” regarding Hydroxychloroquine (HCQ). Kanwal quoted a Fox News interview as the source of his claim.
# A Facebook post falsely claims that ABC chair Ita Buttrose endorsed Donald Trump in the 2020 US presidential election. While Buttrose supported Trump's criticism of Meghan Markle, she did not extend her endorsement to Trump as a leader. Buttrose has not publicly backed any candidate in the election.
# Fact-checking President Trump's farewell speech revealed that while military funding increased during his term, it was lower than Obama's first administration. The US economy did well before the pandemic, but there were periods when it performed better under previous administrations. Trump's claim of producing two vaccines is partially true, as Operation Warp Speed funded Moderna's development. Trump engaged in military actions abroad but started no new wars. The border wall saw 80 miles of new barriers, and unemployment rates for minority groups reached record lows before the pandemic.
# An image circulating online claims to show a tweet by President Trump declaring martial law on December 18, 2020. However, there is no evidence of the tweet on Trump's Twitter account or in a database of deleted tweets. Trump has since denied suggesting martial law.
# President Donald Trump is presenting a lopsided portrait of how the world does business with the U.S to rationalize his escalating trade dispute with allies. At the same time, he's glossing over aspects of the U.S. economy that don't support his faulty contention that it's the best it's ever been.
# A tweet claiming that former Transportation Secretary Elaine Chao called Donald Trump a "Chinese bitch" is false. The tweet is from a satire account and does not appear on Chao's verified Twitter account. There is no record of the tweet on deleted tweet tracker Politwoops, and no credible news reports suggest Chao made such remarks.
# President Trump's claim that water supply policy has worsened California wildfires is baseless. There is no connection between the management of California's surface water supply and wildfires. There is no restriction on the use of water to fight fires, and the dryness of wildlands depends solely on weather, as they are not irrigated.
# A viral video claiming to show football fans watching Trump fire Liz Cheney is actually an altered 2016 video of fans celebrating England's victory against Wales. The video was created by a parody account and combined unrelated footage of Cheney and Trump. The claim is a misrepresentation.
# A viral post claiming that Donald Trump's Twitter account has been reinstated is false. The tweet in question was made by a parody account, @TheUltGmr, not Trump's official account, @realDonaldTrump, which remains suspended since January 2021.
# Hillary Clinton's acceptance speech at the Democratic National Convention has been fact-checked by various sources, with FactCheck.org stating that Clinton misrepresented what Trump said when she suggested he said he could fix everything by himself. FactCheck.Org also reports that Clinton's claim that the top 1% in the country are getting 90% of income gains is an outdated figure, and it is now 52%.
# A flyer claiming that Antifa is urging leftist groups to disguise themselves as Trump supporters for riots after the US election is false. The flyer has been circulating since 2017, and fact-checkers found no evidence of a connection between the flyer and Antifa groups.
# A rumour circulating on Twitter that Donald Trump supporter Robert Kinnison was the police officer who shot and killed Alton Sterling in Baton Rouge, Louisiana, has been proven false. Kinnison is a "Christian, Conservative, gun rights activist" from Lansing, Michigan, not a police officer in Baton Rouge.
# A fake news article claiming that President Trump has signed an executive order allocating $4,106 to every US citizen over the age of 65 has been debunked. The article, which appeared on the Last Line of Defense website, claimed that the measure would cost $40bn, which would be taken from social services such as food stamps and the CHIP program.
# A photo circulating on social media showing former US President Donald Trump holding a sign that reads "The Delta Variant is Fake News" is false. The image has been altered, and the original photo is from a 2017 event.
# Mail-in ballots are protected from fraud through several safeguards, including only sending ballots to valid voters, using hard-to-copy design elements, requiring voters to affirm their identity, using unique mail-ballot envelopes, having the Postal Service flag any oddities, and enforcing strict penalties for voter fraud. These measures make it difficult for individuals to commit voter fraud and nearly impossible to do so on a large scale.
# President Trump's claim that Vice President Mike Pence can reject electoral votes is false. Legal experts, like law professor Rebecca Green, argue that the 12th Amendment and the Electoral Count Act only give the Vice President a ministerial role in presiding over the count of Electoral College votes, not the power to overturn the will of voters.
# A Facebook post claiming that former US President Donald Trump was about to declassify a large number of documents is false. The photo in the post, showing Trump posing next to stacks of paper, is from a 2017 press event where he celebrated rolling back regulations on environmental protections, health care, and other industries. The stacks of paper represent regulations, not classified documents.
# The ad fairly states Booker's role in the passage of criminal justice reform with bipartisan legislation in a Republican-controlled Senate. While questions linger about the charter school strategy in New Jersey, the ad fairly credits Booker for his role in the sweeping changes, which include students now outperforming expectations at the highest rate in the nation, according to one analysis.
# A fake image of a 1998 interview with People Magazine has been debunked, in which Donald Trump allegedly said he would run as a Republican because they are the "dumbest group of voters." People Magazine's extensive online archive shows that Trump was not interviewed by the publication in 1998.
# President Trump's claim that Iran's hostilities increased after the 2013 nuclear deal and that they were given $150 billion is misleading. The deal released about $100 billion in previously frozen Iranian assets, but much of it was tied up by debt obligations. A separate $1.7 billion transfer of cash to Iran was to settle a decades-long dispute and was agreed to in negotiations parallel to the nuclear deal.
# The first presidential debate between Donald Trump and Joe Biden was filled with incorrect, misleading, and out-of-context statements. The debate covered five topics: the candidates' records, the Supreme Court, COVID-19, the economy, race and violence in cities, and the integrity of the election.
# President Trump tweeted false or misleading statements about the election he lost, including claims about Georgia's recount and Pennsylvania's mail-in ballots. Most of these tweets were flagged by Twitter.
# President Donald Trump signed an executive order that could open the door to making good on his promise to sell insurance across state lines. Whether it happens depends on the rules that finally emerge, and that's going to take some time.
# A photo claiming to show a pro-Trump rally in Washington, D.C., on December 12 is actually an aerial view of the March for Our Lives gun control rally held in March 2018. The image was taken by Shannon Finney for Getty Images.
# 34                            Cory Booker  2019-11-29T00:00:00Z
# 35                            Viral Image  2020-05-14T00:00:00Z
# 36                        Donald J. Trump  2020-01-08T00:00:00Z
# 37                      political leaders  2020-09-30T12:17:13Z
# 38                           Donald Trump  2020-11-16T00:00:00Z
# 39                           Donald Trump  2017-03-15T00:00:00Z
# 40                     Social media users  2020-12-12T00:00:00Z
# 41                             FB netizen  2020-03-18T00:00:00Z
# 42                                     NA                    NA
# 43                           Donald Trump  2018-09-20T00:00:00Z
# 44                                     NA                    NA
# 45                                     NA                    NA
# 46                                     NA                    NA
# 47                                     NA                    NA
# 48                               Internet  2018-11-05T00:00:00Z
# 49                     Ravinder Chaudhary  2022-10-28T00:00:00Z
#
#                review_publisher          publisher_site  \
# 0                AFP Fact Check       factcheck.afp.com
# 1                       AP News              apnews.com
# 2                  Africa Check         africacheck.org
# 3                      Alt News              altnews.in
# 4   Australian Associated Press              aap.com.au
# 5                           BBC               bbc.co.uk
# 6                BOOM FactCheck             boomlive.in
# 7                      CBS News             cbsnews.com
# 8               Check Your Fact       checkyourfact.com
# 9              Climate Feedback     climatefeedback.org
# 10               Digiteye India             digiteye.in
# 11                       FACTLY               factly.in
# 12                FactCheck.org           factcheck.org
# 13                   FactRakers          factrakers.org
# 14                    Full Fact            fullfact.org
# 15                     Gigafact            gigafact.org
# 16                         KHOU                khou.com
# 17                         KSDK                ksdk.com
# 18                 Lead Stories         leadstories.com
# 19                           NA             boomlive.in
# 20                  Newschecker          newschecker.in
# 21                    Newsmeter            newsmeter.in
# 22                   Newsmobile           newsmobile.in
# 23                     Newsweek            newsweek.com
# 24               POLYGRAPH.info          polygraph.info
# 25                   PolitiFact          politifact.com
# 26                      Poynter             poynter.org
# 27                      Rappler             rappler.com
# 28                       Snopes              snopes.com
# 29                   Snopes.com              snopes.com
# 30                   THIP Media              thip.media
# 31             The Conversation     theconversation.com
# 32                 The Dispatch         thedispatch.com
# 33      The France 24 Observers  observers.france24.com
# 34                  The Gazette          thegazette.com
# 35                  The Journal           thejournal.ie
# 36           The New York Times             nytimes.com
# 37                    The Quint            thequint.com
# 38          The Washington Post      washingtonpost.com
# 39  Trump-O-Meter: | PolitiFact          politifact.com
# 40                    USA Today            usatoday.com
# 41                   VERA Files           verafiles.org
# 42               VERIFYThis.com          verifythis.com
# 43                          Vox                 vox.com
# 44                     WBIR.com                wbir.com
# 45                         WFAA                wfaa.com
# 46                         WKYC                wkyc.com
# 47                     WTSP.com                wtsp.com
# 48          Washington Examiner  washingtonexaminer.com
# 49              YouTurn English           en.youturn.in
#
#                                            review_url  \
# 0   https://factcheck.afp.com/facebook-posts-share...
# 1   https://apnews.com/article/fact-check-supreme-...
# 2   https://africacheck.org/fact-checks/meta-progr...
# 3   https://www.altnews.in/false-rahul-kanwals-cla...
# 4   https://www.aap.com.au/factcheck/abc-chief-ita...
# 5                 https://www.bbc.co.uk/news/55730719
# 6   https://www.boomlive.in/world/fake-news-donald...
# 7   https://www.cbsnews.com/news/china-trade-defic...
# 8   http://checkyourfact.com/2023/01/18/fact-check...
#
#                                               verdict  \
# 0                                          Misleading
# 1   False. The Supreme Court has not decided to he...
# 2                                               False
# 3                                               False
# 4          False – Content that has no basis in fact.
# 5   This requires context. The Pfizer/BioNTech vac...
# 6                                               False
# 7                                           Not true.
# 8                                               False
# 9                                          Inaccurate
# 10                                              FALSE
# 11                                              FALSE
# 12                          Experts Say Modest Effect
# 13                                              False
# 14  They did not play the song. It was edited over...
# 15                                                 NO
# 16                                              False
# 17  True, Trump is the first former president to b...
# 18                                      Biden Is Prez
# 19                                         Misleading
# 20                                              False
# 21                                              False
# 22                                              False
# 23                                              False
# 24                                              False
# 25                                      Pants on Fire
# 26                                        Mostly True
# 27                                              False
# 28                                              False
# 29                                              False
# 30                                              False
# 31                                              False
# 32                                              false
# 33                                              False
# 34                                                  A
# 35                                              False
# 36                               This is exaggerated.
# 37                                              False
# 38                                              False
# 39                                            Stalled
# 40                                              False
# 41                                              False
# 42  True. New York’s statute of limitations for fe...
# 43                                              False
# 44             False. The video is from October 2020.
# 45  False. Trump can't pardon himself in New York ...
# 46  False, former President Trump couldn't serve 2...
# 47  True. Bank regulations were rolled back under ...
# 48                                              FALSE
# 49                                               Fake
#
#                                              contents  \
# 0   Facebook posts share fabricated Trump tweet fo...
# 1   Supreme Court will not hear case to oust Biden...
# 2   No, Donald Trump didn’t tweet that BEE in Sout...
# 3   False: Rahul Kanwal’s claim about Trump sugges...
# 4   ABC chief Ita Buttrose hasn’t endorsed Donald ...
# 5   President Trump's final day as president fact-...
# 6   Did Donald Trump Declare Martial Law To Preven...
# 7   Fact check: Trump ignores U.S. trade strengths...
# 8   FACT CHECK: Did Elaine Chao Call Trump A ‘Chin...
# 9   President Trump’s claim that water supply poli...
# 10  Video of football fans at pub viewing Trump fi...
# 11  Donald Trump’s Twitter account has been reinst...
# 12  Who’s to Blame for Higher Gas Prices?With gaso...
# 13  Trump didn’t say he can’t handle Americans, ne...
# 14  The ‘Imperial March’ was not played to Donald ...
# 15  Fact Brief : Did Melania Trump 'dump' Donald T...
# 16  Outdated clip used to falsely claim Biden coor...
# 17  Yes, Donald Trump is the first former presiden...
# 18  Fact Check: Flight Radar App Does NOT Show Tru...
# 19  CNN Did Not Say Donald Trump Will Win The US P...
# 20  Donald Trump Back on Twitter? No, Viral claim ...
# 21  Fact check: Viral image of Trump's pic as Hitl...
# 22  Fact Check: Video From Russia Falsely Shared A...
# 23  Fact Check: Has Donald Trump's Plane Been Impo...
# 24  INTERPOL Denies Issuing Red Notices for Donald...
# 25  Mike Pence said Joe Biden copied Trump’s pande...
# 26  6 fact checks you should read on Clinton’s DNC...
# 27  FALSE: Antifa flyer urges patriot disguise for...
# 28  Alton Sterling Killed by Trump Supporter Rober...
# 29  Is President Trump Sending $4,106 to Everyone ...
# 30  Fact Check: Did Donald Trump say that Delta va...
# 31  6 ways mail-in ballots are protected from frau...
# 32  Does Mike Pence Have the Power to Reject Slate...
# 33  No, this photo doesn’t prove Trump is going to...
# 34  Fact Checker: Move over Mayor Pete; there are ...
# 35  Debunked: No, Donald Trump did not say he'd ru...
# 36  Fact Checking Trump's Speech on the Iran Confl...
# 37  Economy to Coronavirus: All That Was False in ...
# 38  Trump’s day on Twitter: Living in an immateria...
# 39  Trump-O-Meter:Update: The administration relea...
# 40  Fact check: Photo depicts 2018 March for Our L...
# 41  VERA FILES FACT CHECK: FB post on Trump announ...
# 42  Yes, New York’s five-year statute of limitatio...
# 43  Trump’s latest interview shows Republicans hav...
# 44  Video claiming to show NYC protest ahead of Tr...
# 45  No, Trump could not pardon himself in New York...
# 46  No, former President Trump could not serve two...
# 47  Yes, bank regulations were rolled back during ...
# 48  Fact Check: Another Fake Maxine Waters Quote“W...
# 49  Trump’s statement congratulating Elon Musk on ...
#
#                                             summaries
# 0   A fabricated tweet attributed to former US Pre...
# 1   The US Supreme Court has rejected a case calli...
# 2   US President Donald Trump did not tweet that S...
# 3   Rahul Kanwal, News director of India Today, cl...
# 4   A Facebook post falsely claims that ABC chair ...
# 5   Fact-checking President Trump's farewell speec...
# 6   An image circulating online claims to show a t...
# 7   President Donald Trump is presenting a lopside...
# 8   A tweet claiming that former Transportation Se...
# 9   President Trump's claim that water supply poli...
# 10  A viral video claiming to show football fans w...
# 11  A viral post claiming that Donald Trump's Twit...
# 12  US President Donald Trump's decision to pull o...
# 13  A pro-Duterte Facebook page manipulated a post...
# 14  A video claiming to show the band of the Grena...
# 15  A clickbait headline claiming Melania Trump "d...
# 16  An outdated video of President Joe Biden is be...
# 17  Donald Trump is the first former US president ...
# 18  A Facebook post claiming that former President...
# 19  A video shared on Facebook claiming that CNN s...
# 20  A viral claim that former US President Donald ...
# 21  A viral image of a Time magazine cover featuri...
# 22  A video claiming to show the arrest of an exec...
# 23  Rumors that Donald Trump's personal plane was ...
# 24  Interpol has denied Iran's claim that it issue...
# 25  Mike Pence claimed that Joe Biden's plan to ad...
# 26  Hillary Clinton's acceptance speech at the Dem...
# 27  A flyer claiming that Antifa is urging leftist...
# 28  A rumour circulating on Twitter that Donald Tr...
# 29  A fake news article claiming that President Tr...
# 30  A photo circulating on social media showing fo...
# 31  Mail-in ballots are protected from fraud throu...
# 32  President Trump's claim that Vice President Mi...
# 33  A Facebook post claiming that former US Presid...
# 34  The ad fairly states Booker's role in the pass...
# 35  A fake image of a 1998 interview with People M...
# 36  President Trump's claim that Iran's hostilitie...
# 37  The first presidential debate between Donald T...
# 38  President Trump tweeted false or misleading st...
# 39  President Donald Trump signed an executive ord...
# 40  A photo claiming to show a pro-Trump rally in ...
# 41  A Facebook post claiming that President Trump ...
# 42  New York's five-year statute of limitations fo...
# 43  President Trump's recent interview with Fox Ne...
# 44  A video claiming to show a pro-Trump crowd in ...
# 45  Donald Trump could not pardon himself of state...
# 46  Former President Trump cannot serve two more t...
# 47  Bank regulations were rolled back during the T...
# 48  A tweet supposedly from California Rep. Maxine...
# 49  A statement claiming to be from Donald Trump c...

# %% [markdown]
# # **Make a CSV file**

# %%
# sample_df.to_csv('test_50urls_50words.csv')
# from google.colab import files
# files.download('test_50urls_50words.csv')
